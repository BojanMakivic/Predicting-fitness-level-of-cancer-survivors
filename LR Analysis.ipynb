# %% [markdown]
# # LINEAR REGRESSION ANALYSIS BETWEEN PERDICTED AND OBSERVED TEST_SET VALUES

# %%
fig = px.scatter(final, x="Observed", y="Predicted", trendline="ols")
fig.show()

results = px.get_trendline_results(fig)
print(results)
# Out:
# px_fit_results
# 0  <statsmodels.regression.linear_model.Regressio...

# %%
results.px_fit_results.iloc[0].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.347
# Model:                            OLS   Adj. R-squared:                  0.346
# Method:                 Least Squares   F-statistic:                     181.5
# Date:                Thu, 17 Sep 2020   Prob (F-statistic):           1.81e-33
# Time:                        20:13:35   Log-Likelihood:                -1560.9
# No. Observations:                 343   AIC:                             3126.
# Df Residuals:                     341   BIC:                             3133.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         70.8855      3.744     18.935      0.000      63.522      78.249
# ...

# %%
import seaborn as sns
sns.residplot(x=final.Observed, y=final.Predicted, lowess=True, color="g") # Residuals look fine

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

model = ols('Predicted ~ Observed', data=final).fit()

#view model summary
print(model.summary())
# Out:
# OLS Regression Results
# ...
# Dep. Variable:              Predicted   R-squared:                       0.347
# Model:                            OLS   Adj. R-squared:                  0.346
# Method:                 Least Squares   F-statistic:                     181.5
# Date:                Thu, 17 Sep 2020   Prob (F-statistic):           1.81e-33
# Time:                        20:26:07   Log-Likelihood:                -1560.9
# No. Observations:                 343   AIC:                             3126.
# Df Residuals:                     341   BIC:                             3133.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     70.8855      3.744     18.935      0.000      63.522      78.249
# Observed       0.4020      0.030     13.474      0.000       0.343       0.461
# ...

# %%
fig2 = plt.figure(figsize=(12,8))
fig2 = sm.graphics.plot_regress_exog(model, 'Observed', fig=fig2)
